# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("HIV data 2000-2023.csv",  encoding='ISO-8859-1')
data2 = pd.read_excel("multidimensional_poverty.xlsx")

# %%
hiv_df = data1.copy()
pov_idx = data2.copy()

# %% [markdown]
# # HIV data

# %%
hiv_df.head()
# Out:
#     IndicatorCode                                          Indicator  \
# 0  HIV_0000000001  Estimated number of people (all ages) living w...
# 1  HIV_0000000001  Estimated number of people (all ages) living w...
# 2  HIV_0000000001  Estimated number of people (all ages) living w...
# 3  HIV_0000000001  Estimated number of people (all ages) living w...
# 4  HIV_0000000001  Estimated number of people (all ages) living w...
#
#   ValueType ParentLocationCode ParentLocation Location type  \
# 0   numeric                AFR         Africa       Country
# 1   numeric                AFR         Africa       Country
# 2   numeric                AFR         Africa       Country
# 3   numeric                AFR         Africa       Country
# 4   numeric                AFR         Africa       Country
#
#   SpatialDimValueCode Location Period type  Period  \
# 0                 AGO   Angola        Year    2023
# 1                 AGO   Angola        Year    2022
# ...

# %%
print ("Hiv data set has", hiv_df.shape[0], "rows and ", hiv_df.shape[1], " columns" )
# Out:
# Hiv data set has 1552 rows and  11  columns

# %%
hiv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IndicatorCode        1552 non-null   object
#  1   Indicator            1552 non-null   object
#  2   ValueType            1552 non-null   object
#  3   ParentLocationCode   1552 non-null   object
#  4   ParentLocation       1552 non-null   object
#  5   Location type        1552 non-null   object
#  6   SpatialDimValueCode  1552 non-null   object
#  7   Location             1552 non-null   object
#  8   Period type          1552 non-null   object
#  9   Period               1552 non-null   int64
#  10  Value                1552 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 133.5+ KB

# %%
hiv_df.isnull().sum()
# Out:
# IndicatorCode          0
# Indicator              0
# ValueType              0
# ParentLocationCode     0
# ParentLocation         0
# Location type          0
# SpatialDimValueCode    0
# Location               0
# Period type            0
# Period                 0
# Value                  0
# dtype: int64

# %%
hiv_df['Estimate'] = hiv_df['Value'].str.extract(r'^(\d+[\s\d]*)')[0].str.replace(" ", "").astype(float)

# %%
hiv_sum = hiv_df.groupby('Location')['HIV_Estimate'].sum().sort_values(ascending=False)
hiv_sum_cumsum = hiv_sum.cumsum() / hiv_sum.sum()
top_countries = hiv_sum_cumsum[hiv_sum_cumsum <= 0.75].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 hiv_sum = hiv_df.groupby('Location')['HIV_Estimate'].sum().sort_values(ascending=False)
#       2 hiv_sum_cumsum = hiv_sum.cumsum() / hiv_sum.sum()
#       3 top_countries = hiv_sum_cumsum[hiv_sum_cumsum <= 0.75].index
#
# NameError: name 'hiv_df' is not defined

# %%
hiv.head(20)
# Out:
#      IndicatorCode                                          Indicator  \
# 0   HIV_0000000001  Estimated number of people (all ages) living w...
# 1   HIV_0000000001  Estimated number of people (all ages) living w...
# 2   HIV_0000000001  Estimated number of people (all ages) living w...
# 3   HIV_0000000001  Estimated number of people (all ages) living w...
# 4   HIV_0000000001  Estimated number of people (all ages) living w...
# 5   HIV_0000000001  Estimated number of people (all ages) living w...
# 6   HIV_0000000001  Estimated number of people (all ages) living w...
# 7   HIV_0000000001  Estimated number of people (all ages) living w...
# 8   HIV_0000000001  Estimated number of people (all ages) living w...
# 9   HIV_0000000001  Estimated number of people (all ages) living w...
# 10  HIV_0000000001  Estimated number of people (all ages) living w...
# 11  HIV_0000000001  Estimated number of people (all ages) living w...
# ...
